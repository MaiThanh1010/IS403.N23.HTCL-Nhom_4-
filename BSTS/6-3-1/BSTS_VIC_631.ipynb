# %%
  from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install prophet
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.1.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.22.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.5.3)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.4.0)
# Requirement already satisfied: holidays>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.25)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.65.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (5.12.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.10/dist-packages (from holidays>=0.14.2->prophet) (0.3.1)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 7.3 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 19.9 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 optuna-3.2.0

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
import numpy as np
import optuna

# %%
# Đọc dữ liệu từ tệp CSV
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/csv/VIC.csv')
# Chuyển đổi cột thời gian thành định dạng datetime
data['Date'] = pd.to_datetime(data['Date'])
# Tạo DataFrame dữ liệu đầu vào
df = pd.DataFrame({'ds': data['Date'], 'y': data['Price']})
df
# Out:
#              ds      y
# 0    2017-12-01  61653
# 1    2017-12-04  62893
# 2    2017-12-05  60331
# 3    2017-12-06  60331
# 4    2017-12-07  59504
# ...         ...    ...
# 1371 2023-06-05  52100
# 1372 2023-06-06  53200
# 1373 2023-06-07  52800
# 1374 2023-06-08  52400
# 1375 2023-06-09  52300
#
# [1376 rows x 2 columns]

# %%
# Chia tập dữ liệu thành train-test-validate theo tỉ lệ
n = len(df)
n_train = int(n * 0.6)
n_test = int(n * 0.3)
n_validate = n - n_train - n_test

train_data = df[:n_train]
test_data = df[n_train:n_train + n_test]
validate_data = df[n_train + n_test:]

# %%
# Hàm mục tiêu để tối ưu hóa
def objective(trial):
    # Xác định không gian tìm kiếm cho siêu tham số
    params = {
        'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
        'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
        'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
    }

    # Xây dựng mô hình BSTS với siêu tham số hiện tại
    model = Prophet(**params)
    model.fit(train_data)

    # Dự đoán trên tập test
    forecast = model.predict(test_data)

    # Tính toán độ đo RMSE để đánh giá mô hình
    rmse = mean_squared_error(test_data['y'], forecast['yhat'], squared=False)

    return rmse

# %%
# Tìm giá trị tối ưu cho siêu tham số
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=350)

# Lấy giá trị tối ưu cho siêu tham số
best_params = study.best_params
# Out:
# Streaming output truncated to the last 5000 lines.
# 16:04:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:04:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:04:17,051] Trial 30 finished with value: 45270.07842150777 and parameters: {'changepoint_prior_scale': 0.018733352063298937, 'seasonality_prior_scale': 0.016064243715356873, 'holidays_prior_scale': 0.29792102757456523}. Best is trial 20 with value: 35395.03693994552.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/kci49jqs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/_7xilr6k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79274', 'data', 'file=/tmp/tmpqyvcxjgq/kci49jqs.json', 'init=/tmp/tmpqyvcxjgq/_7xilr6k.json', 'output', 'file=/tmp/tmpqyvcxjgq/prophet_modelx5hv7lox/prophet_model-20230618160417.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:04:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:04:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:04:18,018] Trial 31 finished with value: 41304.95592083048 and parameters: {'changepoint_prior_scale': 0.01210244579673882, 'seasonality_prior_scale': 0.014163962940438169, 'holidays_prior_scale': 0.48829027783989293}. Best is trial 20 with value: 35395.03693994552.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/lr9srtlo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/ye57w70y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66973', 'data', 'file=/tmp/tmpqyvcxjgq/lr9srtlo.json', 'init=/tmp/tmpqyvcxjgq/ye57w70y.json', 'output', 'file=/tmp/tmpqyvcxjgq/prophet_modelu5k3gt67/prophet_model-20230618160418.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:04:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:04:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:04:18,878] Trial 32 finished with value: 39555.46409342808 and parameters: {'changepoint_prior_scale': 0.03685543997944809, 'seasonality_prior_scale': 0.014538394818679443, 'holidays_prior_scale': 0.7667995483959649}. Best is trial 20 with value: 35395.03693994552.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/_5pbauqv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/su05u6y4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94101', 'data', 'file=/tmp/tmpqyvcxjgq/_5pbauqv.json', 'init=/tmp/tmpqyvcxjgq/su05u6y4.json', 'output', 'file=/tmp/tmpqyvcxjgq/prophet_modelguua73xl/prophet_model-20230618160419.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:04:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:04:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:04:19,524] Trial 33 finished with value: 38144.629642503394 and parameters: {'changepoint_prior_scale': 0.01058195922088699, 'seasonality_prior_scale': 0.03341361705209439, 'holidays_prior_scale': 0.24935616882095632}. Best is trial 20 with value: 35395.03693994552.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq
.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14838', 'data', 'file=/tmp/tmpqyvcxjgq/sieel_lw.json', 'init=/tmp/tmpqyvcxjgq/835j3o9r.json', 'output', 'file=/tmp/tmpqyvcxjgq/prophet_model2rcxx4wv/prophet_model-20230618160733.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:07:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:07:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:07:33,962] Trial 319 finished with value: 40011.07295273817 and parameters: {'changepoint_prior_scale': 0.011301479397448893, 'seasonality_prior_scale': 0.03821742514798697, 'holidays_prior_scale': 1.3343785817550202}. Best is trial 237 with value: 33583.89770517931.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/ti1cnrqh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/3e1406fm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23009', 'data', 'file=/tmp/tmpqyvcxjgq/ti1cnrqh.json', 'init=/tmp/tmpqyvcxjgq/3e1406fm.json', 'output', 'file=/tmp/tmpqyvcxjgq/prophet_modelqqimk6is/prophet_model-20230618160734.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:07:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:07:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:07:34,522] Trial 320 finished with value: 42206.72302449962 and parameters: {'changepoint_prior_scale': 0.012840873134346517, 'seasonality_prior_scale': 0.045888591997416926, 'holidays_prior_scale': 0.3007305400640021}. Best is trial 237 with value: 33583.89770517931.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/l9wc8raq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/tlbmhlcb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76852', 'data', 'file=/tmp/tmpqyvcxjgq/l9wc8raq.json', 'init=/tmp/tmpqyvcxjgq/tlbmhlcb.json', 'output', 'file=/tmp/tmpqyvcxjgq/prophet_model41opednx/prophet_model-20230618160734.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:07:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:07:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:07:35,107] Trial 321 finished with value: 45597.08778237891 and parameters: {'changepoint_prior_scale': 0.023682558917643034, 'seasonality_prior_scale': 0.015897332776246054, 'holidays_prior_scale': 3.9601889476540144}. Best is trial 237 with value: 33583.89770517931.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/31hkyrt9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/hiqphvl0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91047', 'data', 'file=/tmp/tmpqyvcxjgq/31hkyrt9.json', 'init=/tmp/tmpqyvcxjgq/hiqphvl0.json', 'output', 'file=/tmp/tmpqyvcxjgq/prophet_modelkvjq1pl0/prophet_model-20230618160735.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:07:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:07:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:07:35,635] Trial 322 finished with value: 36612.64428596496 and parameters: {'changepoint_prior_scale': 0.010032728088112279, 'seasonality_prior_scale': 0.0192329394631449, 'holidays_prior_scale': 2.077473531566527}. Best is trial 237 with value: 33583.89770517931.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/20eaeh6w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/7ej_o2v5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47137', 'data', 'file=/tmp/tmpqyvcxjgq/20eaeh6w.json', 'init=/tmp/tmpqyvcxjgq/7ej_o2v5.json', 'output', 'file=/tmp/tmpqyvcxjgq/prophet_modelzlghl3ep/prophet_model-20230618160735.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:07:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:07:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:07:36,181] Trial 323 finished with value: 35228.27559788253 and parameters: {'changepoint_prior_scale': 0.010002563911592658, 'seasonality_prior_scale': 0.011888726819615923, 'holidays_prior_scale': 0.17954162991553385}. Best is trial 237 with value: 33583.89770517931.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/bncbtu7q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/qq1icy0l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32726', 'data', 'file=/tmp/tmpqyvcxjgq/bncbtu7q.json', 'init=/tmp/tmpqyvcxjgq/qq1icy0l.json', 'output', 'file=/tmp/tmpqyvcxjgq/prophet_modelncmqt5s5/prophet_model-20230618160736.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:07:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing

# %%
# Xây dựng mô hình BSTS với siêu tham số tốt nhất
best_model = Prophet(**best_params)
best_model.fit(train_data)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/bbj17l9q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqyvcxjgq/amllhlst.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61315', 'data', 'file=/tmp/tmpqyvcxjgq/bbj17l9q.json', 'init=/tmp/tmpqyvcxjgq/amllhlst.json', 'output', 'file=/tmp/tmpqyvcxjgq/prophet_modeli4w2t_b8/prophet_model-20230618161126.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
print("Siêu tham số tối ưu:", best_params)
# Out:
# Siêu tham số tối ưu: {'changepoint_prior_scale': 0.010129349641893319, 'seasonality_prior_scale': 0.01186699752286586, 'holidays_prior_scale': 0.7190458049600658}

# %%
# Dự đoán trên tập test và validate
test_forecast = best_model.predict(test_data)
validate_forecast = best_model.predict(validate_data)

# %%
# Dự đoán 30 ngày tiếp theo
future_dates = pd.date_range(start=df['ds'].max(), periods=30, freq='D')
future_data = pd.DataFrame({'ds': future_dates})

future_forecast = best_model.predict(future_data)

# %%
# In kết quả dự đoán
future_forecast['yhat']
# Out:
# 0     134443.253311
# 1     134032.814480
# 2     134195.579216
# 3     134902.159051
# 4     134939.801125
# 5     135088.617965
# 6     135451.145337
# 7     135579.239687
# 8     135159.018995
# 9     135295.762684
# 10    135960.820643
# 11    135942.511173
# 12    136022.312981
# 13    136304.378278
# 14    136342.379986
# 15    135824.398459
# 16    135857.765026
# 17    136415.914099
# 18    136289.225319
# 19    136261.162435
# 20    136437.737451
# 21    136374.314325
# 22    135760.458747
# 23    135704.752161
# 24    136181.622433
# 25    135982.172982
# 26    135890.317207
# 27    136012.246574
# 28    135903.246255
# 29    135252.564218
# Name: yhat, dtype: float64

# %%
# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(train_data['ds'], train_data['y'], label='Thực tế Train')
plt.plot(test_data['ds'], test_data['y'], label='Thực tế Test')
plt.plot(validate_data['ds'], validate_data['y'], label='Thực tế Validate')
plt.plot(test_data['ds'], test_forecast['yhat'], label='Dự đoán (test)')
plt.plot(validate_data['ds'], validate_forecast['yhat'], label='Dự đoán (validate)')
plt.plot(future_dates, future_forecast['yhat'], label='Dự đoán (30 ngày tiếp theo)')
plt.xlabel('Ngày')
plt.ylabel('Giá trị')
plt.title('So sánh giá trị dự đoán và giá trị thực tế trên tập test và validate')
plt.legend()
plt.show()

# %%
# Tính toán độ đo RMSE, MAPE, MSE, MAE và R2 cho test data
rmse = np.sqrt(mean_squared_error(test_data['y'], test_forecast['yhat']))
mape = mean_absolute_percentage_error(test_data['y'], test_forecast['yhat'])*100
mse = mean_squared_error(test_data['y'], test_forecast['yhat'])
mae = mean_absolute_error(test_data['y'], test_forecast['yhat'])
r2 = r2_score(test_data['y'], test_forecast['yhat'])

print("RMSE:", rmse)
print("MAPE:", mape)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 33583.89770517931
# MAPE: 37.05350634714682
# MSE: 1127878185.0719483
# MAE: 26505.61322626268
# R2: -2.7711358979911846

# %%
# Tính toán độ đo RMSE, MAPE, MSE, MAE và R2 cho validate data
rmse = np.sqrt(mean_squared_error(validate_data['y'], validate_forecast['yhat']))
mape = mean_absolute_percentage_error(validate_data['y'], validate_forecast['yhat'])*100
mse = mean_squared_error(validate_data['y'], validate_forecast['yhat'])
mae = mean_absolute_error(validate_data['y'], validate_forecast['yhat'])
r2 = r2_score(validate_data['y'], validate_forecast['yhat'])

print("RMSE:", rmse)
print("MAPE:", mape)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 73061.51584639007
# MAPE: 132.68201284604154
# MSE: 5337985097.772308
# MAE: 72564.38987783877
# R2: -247.35007147212926
