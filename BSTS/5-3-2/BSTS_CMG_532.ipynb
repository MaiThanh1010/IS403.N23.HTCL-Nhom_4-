# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install prophet
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.1.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.22.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.5.3)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.4.0)
# Requirement already satisfied: holidays>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.25)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.65.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (5.12.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.10/dist-packages (from holidays>=0.14.2->prophet) (0.3.1)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 17.1 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.6 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 optuna-3.2.0

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
import numpy as np
import optuna

# %%
# Đọc dữ liệu từ tệp CSV
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/csv/CMG.csv')
# Chuyển đổi cột thời gian thành định dạng datetime
data['Date'] = pd.to_datetime(data['Date'])
# Tạo DataFrame dữ liệu đầu vào
df = pd.DataFrame({'ds': data['Date'], 'y': data['Price']})
df
# Out:
#              ds      y
# 0    2017-12-01  19753
# 1    2017-12-04  20612
# 2    2017-12-05  21008
# 3    2017-12-06  22065
# 4    2017-12-07  23585
# ...         ...    ...
# 1371 2023-06-05  44050
# 1372 2023-06-06  45700
# 1373 2023-06-07  45500
# 1374 2023-06-08  44500
# 1375 2023-06-09  45500
#
# [1376 rows x 2 columns]

# %%
# Chia tập dữ liệu thành train-test-validate theo tỉ lệ
n = len(df)
n_train = int(n * 0.5)
n_test = int(n * 0.3)
n_validate = n - n_train - n_test

train_data = df[:n_train]
test_data = df[n_train:n_train + n_test]
validate_data = df[n_train + n_test:]

# %%
# Hàm mục tiêu để tối ưu hóa
def objective(trial):
    # Xác định không gian tìm kiếm cho siêu tham số
    params = {
        'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
        'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
        'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
    }

    # Xây dựng mô hình BSTS với siêu tham số hiện tại
    model = Prophet(**params)
    model.fit(train_data)

    # Dự đoán trên tập test
    forecast = model.predict(test_data)

    # Tính toán độ đo RMSE để đánh giá mô hình
    rmse = mean_squared_error(test_data['y'], forecast['yhat'], squared=False)

    return rmse

# %%
# Tìm giá trị tối ưu cho siêu tham số
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=350)

# Lấy giá trị tối ưu cho siêu tham số
best_params = study.best_params
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:13,316] Trial 55 finished with value: 12687.706169691335 and parameters: {'changepoint_prior_scale': 9.57110445032682, 'seasonality_prior_scale': 0.010032178186626217, 'holidays_prior_scale': 0.6848543266350495}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/bdd16a10.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/mla8b95d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75730', 'data', 'file=/tmp/tmp53cqrrkv/bdd16a10.json', 'init=/tmp/tmp53cqrrkv/mla8b95d.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelhx87r72u/prophet_model-20230619112613.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:14,983] Trial 56 finished with value: 14881.291444019862 and parameters: {'changepoint_prior_scale': 9.925169771885587, 'seasonality_prior_scale': 0.014956750705738273, 'holidays_prior_scale': 0.8534592701071617}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/podrgt1w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/w9txxv0l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24930', 'data', 'file=/tmp/tmp53cqrrkv/podrgt1w.json', 'init=/tmp/tmp53cqrrkv/w9txxv0l.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelx7bxsluh/prophet_model-20230619112615.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:16,646] Trial 57 finished with value: 15475.64544991135 and parameters: {'changepoint_prior_scale': 7.422901226954253, 'seasonality_prior_scale': 0.01824631928473973, 'holidays_prior_scale': 0.555848746157552}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/lr81099y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/fwz8tx02.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27692', 'data', 'file=/tmp/tmp53cqrrkv/lr81099y.json', 'init=/tmp/tmp53cqrrkv/fwz8tx02.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelj71sk64n/prophet_model-20230619112616.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:17,566] Trial 58 finished with value: 13521.191995844836 and parameters: {'changepoint_prior_scale': 4.71935935289441, 'seasonality_prior_scale': 0.012907182813675993, 'holidays_prior_scale': 1.0056628168056123}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/iah1axvn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/mq0hekbe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55252', 'data', 'file=/tmp/tmp53cqrrkv/iah1axvn.json', 'init=/tmp/tmp53cqrrkv/mq0hekbe.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_model9inux6tw/prophet_model-20230619112617.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:18,655] Trial 59 finished with value: 12738.433144173676 and parameters: {'changepoint_prior_scale': 9.918615151783575, 'seasonality_prior_scale': 0.010051631358494793, 'holidays_prior_scale': 0.38277098979764446}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/8z57p4t5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/q461ltof.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31394', 'data', 'file=/tmp/tmp53cqrrkv/8z57p4t5.json', 'init=/tmp/tmp53cqrrkv/q461ltof.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelxirkt9yz/prophet_model-20230619112618.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:19,591] Trial 60 finished with value: 14691.70021782523 and parameters: {'changepoint_prior_scale': 5.971645841280778, 'seasonality_prior_scale': 0.016327147458387457, 'holidays_prior_scale': 0.6785334736955176}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/480z1b7l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/2sehu_nr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37393', 'data', 'file=/tmp/tmp53cqrrkv/480z1b7l.json', 'init=/tmp/tmp53cqrrkv/2sehu_nr.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelf47u48qo/prophet_model-20230619112619.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:20,627] Trial 61 finished with value: 12729.643943505494 and parameters: {'changepoint_prior_scale': 7.9275361291602415, 'seasonality_prior_scale': 0.01009126283831221, 'holidays_prior_scale': 0.37520352236559484}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/lh7sqm6i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/lfppfs_h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52462', 'data', 'file=/tmp/tmp53cqrrkv/lh7sqm6i.json', 'init=/tmp/tmp53cqrrkv/lfppfs_h.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_model734e58wf/prophet_model-20230619112620.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:21,533] Trial 62 finished with value: 13433.325083274318 and parameters: {'changepoint_prior_scale': 7.371410482038991, 'seasonality_prior_scale': 0.012362960303156248, 'holidays_prior_scale': 0.3677917973240205}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/40to_81f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/1mx1b_vc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32977', 'data', 'file=/tmp/tmp53cqrrkv/40to_81f.json', 'init=/tmp/tmp53cqrrkv/1mx1b_vc.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_model08mtf36d/prophet_model-20230619112621.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:22,723] Trial 63 finished with value: 13353.22207939352 and parameters: {'changepoint_prior_scale': 4.022107081746773, 'seasonality_prior_scale': 0.011333499072169358, 'holidays_prior_scale': 0.2152903891689276}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/c5gyacgf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/p5s60jez.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28547', 'data', 'file=/tmp/tmp53cqrrkv/c5gyacgf.json', 'init=/tmp/tmp53cqrrkv/p5s60jez.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_model_gndwvvu/prophet_model-20230619112622.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:23,639] Trial 64 finished with value: 14208.305800794556 and parameters: {'changepoint_prior_scale': 7.60938370741082, 'seasonality_prior_scale': 0.014534271959231154, 'holidays_prior_scale': 0.45613492201328254}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/n9ffa9nz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/zc2wu22t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66466', 'data', 'file=/tmp/tmp53cqrrkv/n9ffa9nz.json', 'init=/tmp/tmp53cqrrkv/zc2wu22t.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modeleyl7jiyu/prophet_model-20230619112623.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:24,722] Trial 65 finished with value: 13429.380449041826 and parameters: {'changepoint_prior_scale': 9.923555225901588, 'seasonality_prior_scale': 0.011849893430848024, 'holidays_prior_scale': 0.6674242226260853}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/666i4e_0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/pk7xz88z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85852', 'data', 'file=/tmp/tmp53cqrrkv/666i4e_0.json', 'init=/tmp/tmp53cqrrkv/pk7xz88z.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_model3iatran7/prophet_model-20230619112624.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:25,718] Trial 66 finished with value: 15716.37622852471 and parameters: {'changepoint_prior_scale': 5.645431149912182, 'seasonality_prior_scale': 0.019945158183636985, 'holidays_prior_scale': 0.3788053207207966}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/e3gnjlou.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/d0g_q4vt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7612', 'data', 'file=/tmp/tmp53cqrrkv/e3gnjlou.json', 'init=/tmp/tmp53cqrrkv/d0g_q4vt.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_model88vkked9/prophet_model-20230619112625.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:26,806] Trial 67 finished with value: 14097.425470498027 and parameters: {'changepoint_prior_scale': 4.705903419886401, 'seasonality_prior_scale': 0.013962812140632583, 'holidays_prior_scale': 0.8542716759480504}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/h4d40q3d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/t58e68m9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77653', 'data', 'file=/tmp/tmp53cqrrkv/h4d40q3d.json', 'init=/tmp/tmp53cqrrkv/t58e68m9.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelw5o17utw/prophet_model-20230619112626.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:28,444] Trial 68 finished with value: 12770.026534730057 and parameters: {'changepoint_prior_scale': 6.413896943610999, 'seasonality_prior_scale': 0.010115248976563084, 'holidays_prior_scale': 0.3116357378963068}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/2ez2ulr1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/s6c_tg0t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1510', 'data', 'file=/tmp/tmp53cqrrkv/2ez2ulr1.json', 'init=/tmp/tmp53cqrrkv/s6c_tg0t.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_model3nygmcri/prophet_model-20230619112628.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:30,170] Trial 69 finished with value: 13563.211581980215 and parameters: {'changepoint_prior_scale': 7.900434548375525, 'seasonality_prior_scale': 0.011614617259573988, 'holidays_prior_scale': 0.5127306829971584}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/bcq0nolz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/ui4qp20_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83358', 'data', 'file=/tmp/tmp53cqrrkv/bcq0nolz.json', 'init=/tmp/tmp53cqrrkv/ui4qp20_.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelujlen594/prophet_model-20230619112630.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:31,724] Trial 70 finished with value: 14596.540221088939 and parameters: {'changepoint_prior_scale': 3.755484855997083, 'seasonality_prior_scale': 0.0163700226070912, 'holidays_prior_scale': 0.17946255202521652}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/_7hr5x2v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/49h40f2i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19441', 'data', 'file=/tmp/tmp53cqrrkv/_7hr5x2v.json', 'init=/tmp/tmp53cqrrkv/49h40f2i.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modeloot_sy35/prophet_model-20230619112631.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:32,836] Trial 71 finished with value: 12837.975026643848 and parameters: {'changepoint_prior_scale': 9.821500371892439, 'seasonality_prior_scale': 0.010172245323548079, 'holidays_prior_scale': 0.4951178672820867}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/4u8hlkgq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/hjqvw5hp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63191', 'data', 'file=/tmp/tmp53cqrrkv/4u8hlkgq.json', 'init=/tmp/tmp53cqrrkv/hjqvw5hp.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelubbb0h9s/prophet_model-20230619112632.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:33,808] Trial 72 finished with value: 13840.702286669188 and parameters: {'changepoint_prior_scale': 8.208996084428362, 'seasonality_prior_scale': 0.0134923557679714, 'holidays_prior_scale': 0.2625419621062769}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/u8444kuq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/hlihzbcl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29940', 'data', 'file=/tmp/tmp53cqrrkv/u8444kuq.json', 'init=/tmp/tmp53cqrrkv/hlihzbcl.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modeleymo8yhs/prophet_model-20230619112633.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:34,729] Trial 73 finished with value: 13129.642459846838 and parameters: {'changepoint_prior_scale': 5.418833315679034, 'seasonality_prior_scale': 0.011305579497022393, 'holidays_prior_scale': 0.4239692937222887}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/vd3tj0fj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/pxek4h3q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12127', 'data', 'file=/tmp/tmp53cqrrkv/vd3tj0fj.json', 'init=/tmp/tmp53cqrrkv/pxek4h3q.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelzk1zhl0_/prophet_model-20230619112634.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:35,733] Trial 74 finished with value: 14055.44286837333 and parameters: {'changepoint_prior_scale': 6.461328854301696, 'seasonality_prior_scale': 0.013238715450364208, 'holidays_prior_scale': 0.7421800362801158}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/bpftd3zw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/hx38_u5m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20940', 'data', 'file=/tmp/tmp53cqrrkv/bpftd3zw.json', 'init=/tmp/tmp53cqrrkv/hx38_u5m.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_model0ywswt46/prophet_model-20230619112635.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:36,697] Trial 75 finished with value: 12637.161691749294 and parameters: {'changepoint_prior_scale': 8.928988742341998, 'seasonality_prior_scale': 0.010031520804507782, 'holidays_prior_scale': 0.2267577675431527}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/xq3zxxz1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/ab8m2u46.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76975', 'data', 'file=/tmp/tmp53cqrrkv/xq3zxxz1.json', 'init=/tmp/tmp53cqrrkv/ab8m2u46.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelpt6kn6wy/prophet_model-20230619112636.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:37,672] Trial 76 finished with value: 15236.065924686183 and parameters: {'changepoint_prior_scale': 8.222838766823752, 'seasonality_prior_scale': 0.018200301870464706, 'holidays_prior_scale': 0.2218468766642209}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/ue6ubz6w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/h2u4dgiz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22810', 'data', 'file=/tmp/tmp53cqrrkv/ue6ubz6w.json', 'init=/tmp/tmp53cqrrkv/h2u4dgiz.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelkltstqi8/prophet_model-20230619112637.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:26:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:26:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:26:38,590] Trial 77 finished with value: 14690.077660709085 and parameters: {'changepoint_prior_scale': 4.668536229946277, 'seasonality_prior_scale': 0.0154340280440436, 'holidays_prior_scale': 0.3557319961510845}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# ...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/9i6pacq3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/0k7yru65.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87462', 'data', 'file=/tmp/tmp53cqrrkv/9i6pacq3.json', 'init=/tmp/tmp53cqrrkv/0k7yru65.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_model3mjf7p7t/prophet_model-20230619113204.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:32:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:32:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:32:05,802] Trial 342 finished with value: 13679.330868659685 and parameters: {'changepoint_prior_scale': 8.848194967393727, 'seasonality_prior_scale': 0.012849416754202217, 'holidays_prior_scale': 0.4839420539939675}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/22__rs1i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/9ww6u5n1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59197', 'data', 'file=/tmp/tmp53cqrrkv/22__rs1i.json', 'init=/tmp/tmp53cqrrkv/9ww6u5n1.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelyr6tvvcr/prophet_model-20230619113205.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:32:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:32:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:32:06,843] Trial 343 finished with value: 13032.198367708454 and parameters: {'changepoint_prior_scale': 9.995703744878423, 'seasonality_prior_scale': 0.010932871502527449, 'holidays_prior_scale': 0.3005352713410341}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/sg40lwrg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/rptl58_i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86027', 'data', 'file=/tmp/tmp53cqrrkv/sg40lwrg.json', 'init=/tmp/tmp53cqrrkv/rptl58_i.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelr0hg8jrh/prophet_model-20230619113206.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:32:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:32:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:32:07,993] Trial 344 finished with value: 20556.05227098826 and parameters: {'changepoint_prior_scale': 1.0677935977655986, 'seasonality_prior_scale': 0.06983377228444879, 'holidays_prior_scale': 0.42492772691499536}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/mvdz97ta.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/p1wtw96s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92846', 'data', 'file=/tmp/tmp53cqrrkv/mvdz97ta.json', 'init=/tmp/tmp53cqrrkv/p1wtw96s.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelnq4ggo2q/prophet_model-20230619113208.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:32:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:32:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:32:09,006] Trial 345 finished with value: 14220.151466428433 and parameters: {'changepoint_prior_scale': 8.259353589049613, 'seasonality_prior_scale': 0.015526147849448106, 'holidays_prior_scale': 0.04377352112530712}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/o2nxefen.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/ebzfo1i4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60835', 'data', 'file=/tmp/tmp53cqrrkv/o2nxefen.json', 'init=/tmp/tmp53cqrrkv/ebzfo1i4.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelhoe2g69p/prophet_model-20230619113209.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:32:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:32:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:32:10,633] Trial 346 finished with value: 16779.72435409713 and parameters: {'changepoint_prior_scale': 8.023339716519098, 'seasonality_prior_scale': 0.029149412439247905, 'holidays_prior_scale': 0.07555434713177385}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/k64o0bgg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/gchzd0pq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53296', 'data', 'file=/tmp/tmp53cqrrkv/k64o0bgg.json', 'init=/tmp/tmp53cqrrkv/gchzd0pq.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modellew8pu_h/prophet_model-20230619113210.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:32:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:32:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:32:12,935] Trial 347 finished with value: 21655.06043412849 and parameters: {'changepoint_prior_scale': 9.03903609001892, 'seasonality_prior_scale': 0.05326363668082164, 'holidays_prior_scale': 0.014755591792117138}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/w88pv3mz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/k7n6yvps.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20921', 'data', 'file=/tmp/tmp53cqrrkv/w88pv3mz.json', 'init=/tmp/tmp53cqrrkv/k7n6yvps.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelj5n0b8f9/prophet_model-20230619113213.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:32:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:32:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:32:14,566] Trial 348 finished with value: 13309.767793007948 and parameters: {'changepoint_prior_scale': 6.9776666312820375, 'seasonality_prior_scale': 0.010928593861186019, 'holidays_prior_scale': 0.06002879202404877}. Best is trial 51 with value: 12476.190718534532.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/uyjal231.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/q1hbsc41.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45064', 'data', 'file=/tmp/tmp53cqrrkv/uyjal231.json', 'init=/tmp/tmp53cqrrkv/q1hbsc41.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelgxqm95tx/prophet_model-20230619113214.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:32:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:32:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-19 11:32:15,628] Trial 349 finished with value: 12873.912366351398 and parameters: {'changepoint_prior_scale': 4.209970814391591, 'seasonality_prior_scale': 0.010017647843086386, 'holidays_prior_scale': 0.4704635453196223}. Best is trial 51 with value: 12476.190718534532.

# %%
# Xây dựng mô hình BSTS với siêu tham số tốt nhất
best_model = Prophet(**best_params)
best_model.fit(train_data)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/ta5g642f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp53cqrrkv/h25j1i08.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49081', 'data', 'file=/tmp/tmp53cqrrkv/ta5g642f.json', 'init=/tmp/tmp53cqrrkv/h25j1i08.json', 'output', 'file=/tmp/tmp53cqrrkv/prophet_modelrrduu7ou/prophet_model-20230619113215.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:32:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:32:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
print("Siêu tham số tối ưu:", best_params)
# Out:
# Siêu tham số tối ưu: {'changepoint_prior_scale': 9.441159495416084, 'seasonality_prior_scale': 0.010118423810123185, 'holidays_prior_scale': 0.5720480562915107}

# %%
# Dự đoán trên tập test và validate
test_forecast = best_model.predict(test_data)
validate_forecast = best_model.predict(validate_data)

# %%
# Dự đoán 30 ngày tiếp theo
future_dates = pd.date_range(start=df['ds'].max(), periods=30, freq='D')
future_data = pd.DataFrame({'ds': future_dates})

future_forecast = best_model.predict(future_data)

# %%
# In kết quả dự đoán
future_forecast['yhat']
# Out:
# 0     37753.998213
# 1     37797.461389
# 2     37844.650229
# 3     37864.097321
# 4     37953.668877
# 5     37983.039652
# 6     38014.678701
# 7     38038.852804
# 8     38054.958209
# 9     38070.201728
# 10    38054.109531
# 11    38105.666405
# 12    38095.752940
# 13    38088.090583
# 14    38074.202757
# 15    38054.704048
# 16    38037.939929
# 17    37994.456701
# 18    38024.105722
# 19    37998.450548
# 20    37981.687931
# 21    37965.591713
# 22    37950.792200
# 23    37945.413875
# 24    37919.551234
# 25    37972.386701
# 26    37974.618840
# 27    37989.411208
# 28    38007.370014
# 29    38027.862158
# Name: yhat, dtype: float64

# %%
# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(train_data['ds'], train_data['y'], label='Thực tế Train')
plt.plot(test_data['ds'], test_data['y'], label='Thực tế Test')
plt.plot(validate_data['ds'], validate_data['y'], label='Thực tế Validate')
plt.plot(test_data['ds'], test_forecast['yhat'], label='Dự đoán (test)')
plt.plot(validate_data['ds'], validate_forecast['yhat'], label='Dự đoán (validate)')
plt.plot(future_dates, future_forecast['yhat'], label='Dự đoán (30 ngày tiếp theo)')
plt.xlabel('Ngày')
plt.ylabel('Giá trị')
plt.title('So sánh giá trị dự đoán và giá trị thực tế trên tập test và validate')
plt.legend()
plt.show()

# %%
# Tính toán độ đo RMSE, MAPE, MSE, MAE và R2 cho test data
rmse = np.sqrt(mean_squared_error(test_data['y'], test_forecast['yhat']))
mape = mean_absolute_percentage_error(test_data['y'], test_forecast['yhat'])*100
mse = mean_squared_error(test_data['y'], test_forecast['yhat'])
mae = mean_absolute_error(test_data['y'], test_forecast['yhat'])
r2 = r2_score(test_data['y'], test_forecast['yhat'])

print("RMSE:", rmse)
print("MAPE:", mape)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 12476.190718534532
# MAPE: 19.734142022247557
# MSE: 155655334.84524718
# MAE: 9022.772036634477
# R2: -0.33970761684171635

# %%
# Tính toán độ đo RMSE, MAPE, MSE, MAE và R2 cho validate data
rmse = np.sqrt(mean_squared_error(validate_data['y'], validate_forecast['yhat']))
mape = mean_absolute_percentage_error(validate_data['y'], validate_forecast['yhat'])*100
mse = mean_squared_error(validate_data['y'], validate_forecast['yhat'])
mae = mean_absolute_error(validate_data['y'], validate_forecast['yhat'])
r2 = r2_score(validate_data['y'], validate_forecast['yhat'])

print("RMSE:", rmse)
print("MAPE:", mape)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 12287.306273287957
# MAPE: 19.590919650389534
# MSE: 150977895.4535816
# MAE: 9652.505415260788
# R2: -2.54326706326052
