# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install prophet
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.1.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.22.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.5.3)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.4.0)
# Requirement already satisfied: holidays>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.25)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.65.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (5.12.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.10/dist-packages (from holidays>=0.14.2->prophet) (0.3.1)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 11.5 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 20.3 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 optuna-3.2.0

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
import numpy as np
import optuna

# %%
# Đọc dữ liệu từ tệp CSV
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/csv/CMG.csv')
# Chuyển đổi cột thời gian thành định dạng datetime
data['Date'] = pd.to_datetime(data['Date'])
# Tạo DataFrame dữ liệu đầu vào
df = pd.DataFrame({'ds': data['Date'], 'y': data['Price']})
df
# Out:
#              ds      y
# 0    2017-12-01  19753
# 1    2017-12-04  20612
# 2    2017-12-05  21008
# 3    2017-12-06  22065
# 4    2017-12-07  23585
# ...         ...    ...
# 1371 2023-06-05  44050
# 1372 2023-06-06  45700
# 1373 2023-06-07  45500
# 1374 2023-06-08  44500
# 1375 2023-06-09  45500
#
# [1376 rows x 2 columns]

# %%
# Chia tập dữ liệu thành train-test-validate theo tỉ lệ
n = len(df)
n_train = int(n * 0.7)
n_test = int(n * 0.2)
n_validate = n - n_train - n_test

train_data = df[:n_train]
test_data = df[n_train:n_train + n_test]
validate_data = df[n_train + n_test:]

# %%
# Hàm mục tiêu để tối ưu hóa
def objective(trial):
    # Xác định không gian tìm kiếm cho siêu tham số
    params = {
        'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
        'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
        'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
    }

    # Xây dựng mô hình BSTS với siêu tham số hiện tại
    model = Prophet(**params)
    model.fit(train_data)

    # Dự đoán trên tập test
    forecast = model.predict(test_data)

    # Tính toán độ đo RMSE để đánh giá mô hình
    rmse = mean_squared_error(test_data['y'], forecast['yhat'], squared=False)

    return rmse

# %%
# Tìm giá trị tối ưu cho siêu tham số
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=350)

# Lấy giá trị tối ưu cho siêu tham số
best_params = study.best_params
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:04,008] Trial 55 finished with value: 9454.30848460616 and parameters: {'changepoint_prior_scale': 0.01750239215364029, 'seasonality_prior_scale': 0.12232158986465615, 'holidays_prior_scale': 3.1715815801806926}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/o3a4_s3z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/ze4sw9bw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23782', 'data', 'file=/tmp/tmptdsgc936/o3a4_s3z.json', 'init=/tmp/tmptdsgc936/ze4sw9bw.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelkjw525a4/prophet_model-20230618163204.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:04,481] Trial 56 finished with value: 9386.162889382435 and parameters: {'changepoint_prior_scale': 0.012069930798312617, 'seasonality_prior_scale': 0.06570062100920995, 'holidays_prior_scale': 1.5483390443401779}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/gnwvpp3e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/qgjuixa0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28254', 'data', 'file=/tmp/tmptdsgc936/gnwvpp3e.json', 'init=/tmp/tmptdsgc936/qgjuixa0.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelrntt_gzh/prophet_model-20230618163204.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:05,001] Trial 57 finished with value: 9665.585089446826 and parameters: {'changepoint_prior_scale': 0.030367122915395048, 'seasonality_prior_scale': 0.06742674818174389, 'holidays_prior_scale': 0.7500324868816343}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/hfq0aalf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/rc2oy6up.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55455', 'data', 'file=/tmp/tmptdsgc936/hfq0aalf.json', 'init=/tmp/tmptdsgc936/rc2oy6up.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modela3jhahtv/prophet_model-20230618163205.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:05,483] Trial 58 finished with value: 9506.136958928608 and parameters: {'changepoint_prior_scale': 0.0224866152825725, 'seasonality_prior_scale': 0.06016609402815589, 'holidays_prior_scale': 1.5065450786390409}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/zwzz77s9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/t8v_59ji.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88949', 'data', 'file=/tmp/tmptdsgc936/zwzz77s9.json', 'init=/tmp/tmptdsgc936/t8v_59ji.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelyah98my_/prophet_model-20230618163205.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:05,898] Trial 59 finished with value: 9387.351734271064 and parameters: {'changepoint_prior_scale': 0.013739099539285237, 'seasonality_prior_scale': 0.1695028554208163, 'holidays_prior_scale': 1.9412377499487088}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/nknblt2d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/3kcjzrqo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99595', 'data', 'file=/tmp/tmptdsgc936/nknblt2d.json', 'init=/tmp/tmptdsgc936/3kcjzrqo.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelnd_4hxjy/prophet_model-20230618163206.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:06,334] Trial 60 finished with value: 9395.52614925423 and parameters: {'changepoint_prior_scale': 0.012227068308000999, 'seasonality_prior_scale': 0.16578231042993058, 'holidays_prior_scale': 4.266333527003392}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/4f5rdpuz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/9miag83t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76890', 'data', 'file=/tmp/tmptdsgc936/4f5rdpuz.json', 'init=/tmp/tmptdsgc936/9miag83t.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelu37asprt/prophet_model-20230618163206.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:06,785] Trial 61 finished with value: 9413.180921796975 and parameters: {'changepoint_prior_scale': 0.01572390931957098, 'seasonality_prior_scale': 0.12209421119909886, 'holidays_prior_scale': 1.9482804435215886}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/tq_ejq4b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/6d3wh55x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13899', 'data', 'file=/tmp/tmptdsgc936/tq_ejq4b.json', 'init=/tmp/tmptdsgc936/6d3wh55x.json', 'output', 'file=/tmp/tmptdsgc936/prophet_model2k8gjql_/prophet_model-20230618163206.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:07,202] Trial 62 finished with value: 9393.01197684476 and parameters: {'changepoint_prior_scale': 0.012334406567266738, 'seasonality_prior_scale': 0.19086529711074596, 'holidays_prior_scale': 1.3096399593074082}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/7wquj1kx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/lvsgl4z6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51448', 'data', 'file=/tmp/tmptdsgc936/7wquj1kx.json', 'init=/tmp/tmptdsgc936/lvsgl4z6.json', 'output', 'file=/tmp/tmptdsgc936/prophet_model4argkwzm/prophet_model-20230618163207.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:07,677] Trial 63 finished with value: 9476.081793479587 and parameters: {'changepoint_prior_scale': 0.020734507303774168, 'seasonality_prior_scale': 0.13876492348343847, 'holidays_prior_scale': 2.997440137627658}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/8cu4mi0r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/gb2vexrc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63495', 'data', 'file=/tmp/tmptdsgc936/8cu4mi0r.json', 'init=/tmp/tmptdsgc936/gb2vexrc.json', 'output', 'file=/tmp/tmptdsgc936/prophet_model0c4mvmny/prophet_model-20230618163207.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:08,292] Trial 64 finished with value: 9418.779045807367 and parameters: {'changepoint_prior_scale': 0.012441862080415686, 'seasonality_prior_scale': 0.07701803579368136, 'holidays_prior_scale': 1.9980001317426284}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/ppasnn4a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/smdhakaz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39096', 'data', 'file=/tmp/tmptdsgc936/ppasnn4a.json', 'init=/tmp/tmptdsgc936/smdhakaz.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modeltyywq5f7/prophet_model-20230618163208.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:08,741] Trial 65 finished with value: 9417.755939365628 and parameters: {'changepoint_prior_scale': 0.016400437484074566, 'seasonality_prior_scale': 0.1011267616877452, 'holidays_prior_scale': 1.5397077488061839}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/8jqd68qk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/13hesjyg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85863', 'data', 'file=/tmp/tmptdsgc936/8jqd68qk.json', 'init=/tmp/tmptdsgc936/13hesjyg.json', 'output', 'file=/tmp/tmptdsgc936/prophet_model3ow8fbmb/prophet_model-20230618163208.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:09,168] Trial 66 finished with value: 9377.39039120721 and parameters: {'changepoint_prior_scale': 0.010342779922843626, 'seasonality_prior_scale': 0.16105342973373676, 'holidays_prior_scale': 1.042924439955508}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/gk2w3j_u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/h5x8sej5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19675', 'data', 'file=/tmp/tmptdsgc936/gk2w3j_u.json', 'init=/tmp/tmptdsgc936/h5x8sej5.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modele34b7hxp/prophet_model-20230618163209.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:09,642] Trial 67 finished with value: 9524.599328790986 and parameters: {'changepoint_prior_scale': 0.023747913008268264, 'seasonality_prior_scale': 0.2309078932225266, 'holidays_prior_scale': 1.0749505150095031}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/q0o3wexn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/aowgg4tq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59494', 'data', 'file=/tmp/tmptdsgc936/q0o3wexn.json', 'init=/tmp/tmptdsgc936/aowgg4tq.json', 'output', 'file=/tmp/tmptdsgc936/prophet_models9outy26/prophet_model-20230618163209.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:10,132] Trial 68 finished with value: 9419.130288930197 and parameters: {'changepoint_prior_scale': 0.010990709318765498, 'seasonality_prior_scale': 0.17312852277306112, 'holidays_prior_scale': 0.8837355411915648}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/w7kyps5m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/iv7uf8mj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86023', 'data', 'file=/tmp/tmptdsgc936/w7kyps5m.json', 'init=/tmp/tmptdsgc936/iv7uf8mj.json', 'output', 'file=/tmp/tmptdsgc936/prophet_model39i6cmpk/prophet_model-20230618163210.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:10,606] Trial 69 finished with value: 9435.878992970333 and parameters: {'changepoint_prior_scale': 0.01679795695007013, 'seasonality_prior_scale': 0.18448859942765536, 'holidays_prior_scale': 0.7007143529197286}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/_rb79hnk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/p2i4vde2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64101', 'data', 'file=/tmp/tmptdsgc936/_rb79hnk.json', 'init=/tmp/tmptdsgc936/p2i4vde2.json', 'output', 'file=/tmp/tmptdsgc936/prophet_model01jn7j71/prophet_model-20230618163210.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:11,213] Trial 70 finished with value: 9419.006370061283 and parameters: {'changepoint_prior_scale': 0.010128290703206163, 'seasonality_prior_scale': 0.15106255566483784, 'holidays_prior_scale': 1.1262676510390683}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/ryfmxhhh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/j24z5wit.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56817', 'data', 'file=/tmp/tmptdsgc936/ryfmxhhh.json', 'init=/tmp/tmptdsgc936/j24z5wit.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelzko08khv/prophet_model-20230618163211.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:11,916] Trial 71 finished with value: 9394.514269387504 and parameters: {'changepoint_prior_scale': 0.014140827590214892, 'seasonality_prior_scale': 0.12033606892415055, 'holidays_prior_scale': 2.3044772559800153}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/espbxp1k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/sx7xw4ez.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61011', 'data', 'file=/tmp/tmptdsgc936/espbxp1k.json', 'init=/tmp/tmptdsgc936/sx7xw4ez.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelknq2ubh9/prophet_model-20230618163212.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:12,501] Trial 72 finished with value: 9399.391126769115 and parameters: {'changepoint_prior_scale': 0.01256980101143342, 'seasonality_prior_scale': 0.08495498983551435, 'holidays_prior_scale': 1.6777977362011507}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/s9tztxfc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/gshxo2cp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92355', 'data', 'file=/tmp/tmptdsgc936/s9tztxfc.json', 'init=/tmp/tmptdsgc936/gshxo2cp.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelr1wkz6bb/prophet_model-20230618163212.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:13,452] Trial 73 finished with value: 9554.31298200077 and parameters: {'changepoint_prior_scale': 0.021692666666654252, 'seasonality_prior_scale': 0.09647840273281301, 'holidays_prior_scale': 1.4226400332023181}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/w6gebinn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/nade86x3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67548', 'data', 'file=/tmp/tmptdsgc936/w6gebinn.json', 'init=/tmp/tmptdsgc936/nade86x3.json', 'output', 'file=/tmp/tmptdsgc936/prophet_model99pba9z8/prophet_model-20230618163213.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:14,179] Trial 74 finished with value: 9423.633541216317 and parameters: {'changepoint_prior_scale': 0.016842765368381134, 'seasonality_prior_scale': 0.32474698916700023, 'holidays_prior_scale': 2.6255747328712955}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/k8ae3ljh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/vs74bloa.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48993', 'data', 'file=/tmp/tmptdsgc936/k8ae3ljh.json', 'init=/tmp/tmptdsgc936/vs74bloa.json', 'output', 'file=/tmp/tmptdsgc936/prophet_model2l7nh__e/prophet_model-20230618163214.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:14,902] Trial 75 finished with value: 9435.89285307246 and parameters: {'changepoint_prior_scale': 0.01014428740812342, 'seasonality_prior_scale': 0.06992575388899999, 'holidays_prior_scale': 0.8824771889015205}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/d31fx1wy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/ujrfkd5i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58714', 'data', 'file=/tmp/tmptdsgc936/d31fx1wy.json', 'init=/tmp/tmptdsgc936/ujrfkd5i.json', 'output', 'file=/tmp/tmptdsgc936/prophet_model3zsej_ke/prophet_model-20230618163215.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:15,518] Trial 76 finished with value: 9396.566668065665 and parameters: {'changepoint_prior_scale': 0.014681987975512638, 'seasonality_prior_scale': 0.13225250685557308, 'holidays_prior_scale': 1.2333208620330276}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/9w0kke9z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/_nwh3090.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43845', 'data', 'file=/tmp/tmptdsgc936/9w0kke9z.json', 'init=/tmp/tmptdsgc936/_nwh3090.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelzkn3z3pk/prophet_model-20230618163215.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:16,252] Trial 77 finished with value: 9632.482045255165 and parameters: {'changepoint_prior_scale': 0.030234220077997982, 'seasonality_prior_scale': 0.11157734397801458, 'holidays_prior_scale': 2.157704464859027}. Best is trial 54 with value: 9344.617931634046.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# ...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/6stqq65k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/m64xlbak.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74789', 'data', 'file=/tmp/tmptdsgc936/6stqq65k.json', 'init=/tmp/tmptdsgc936/m64xlbak.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelpufew03q/prophet_model-20230618163501.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:35:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:35:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:35:01,521] Trial 342 finished with value: 9419.411994912662 and parameters: {'changepoint_prior_scale': 0.01568218487379185, 'seasonality_prior_scale': 0.6709341735131202, 'holidays_prior_scale': 1.5129960928967368}. Best is trial 300 with value: 9343.579842324094.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/wdtdwagd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/uub2opl0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7939', 'data', 'file=/tmp/tmptdsgc936/wdtdwagd.json', 'init=/tmp/tmptdsgc936/uub2opl0.json', 'output', 'file=/tmp/tmptdsgc936/prophet_model4di5tc0l/prophet_model-20230618163501.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:35:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:35:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:35:02,029] Trial 343 finished with value: 9391.17756609929 and parameters: {'changepoint_prior_scale': 0.011743482026513654, 'seasonality_prior_scale': 0.5367667666305019, 'holidays_prior_scale': 0.20641804009851175}. Best is trial 300 with value: 9343.579842324094.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/_29ndk2c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/8u8lxpt3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74522', 'data', 'file=/tmp/tmptdsgc936/_29ndk2c.json', 'init=/tmp/tmptdsgc936/8u8lxpt3.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelvecgajaw/prophet_model-20230618163502.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:35:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:35:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:35:02,535] Trial 344 finished with value: 9390.853822612271 and parameters: {'changepoint_prior_scale': 0.014025209385305673, 'seasonality_prior_scale': 0.42394288218929777, 'holidays_prior_scale': 0.3648929099485022}. Best is trial 300 with value: 9343.579842324094.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/rgtd2xh2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/ihnjy4ro.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85889', 'data', 'file=/tmp/tmptdsgc936/rgtd2xh2.json', 'init=/tmp/tmptdsgc936/ihnjy4ro.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelawgl8ud8/prophet_model-20230618163502.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:35:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:35:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:35:02,974] Trial 345 finished with value: 9332.17207434874 and parameters: {'changepoint_prior_scale': 0.011343415803277296, 'seasonality_prior_scale': 0.10089247365741379, 'holidays_prior_scale': 1.2144562294568646}. Best is trial 345 with value: 9332.17207434874.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/d_y_jy06.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/t8w8ij__.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29257', 'data', 'file=/tmp/tmptdsgc936/d_y_jy06.json', 'init=/tmp/tmptdsgc936/t8w8ij__.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelensipfwf/prophet_model-20230618163503.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:35:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:35:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:35:03,485] Trial 346 finished with value: 9875.724748599545 and parameters: {'changepoint_prior_scale': 0.04552491476907363, 'seasonality_prior_scale': 0.10795577685996025, 'holidays_prior_scale': 1.1906819918075622}. Best is trial 345 with value: 9332.17207434874.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/d2026a2f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/xtcalww5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=205', 'data', 'file=/tmp/tmptdsgc936/d2026a2f.json', 'init=/tmp/tmptdsgc936/xtcalww5.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelhp64yxjo/prophet_model-20230618163503.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:35:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:35:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:35:03,865] Trial 347 finished with value: 9347.871418303059 and parameters: {'changepoint_prior_scale': 0.011668873626875317, 'seasonality_prior_scale': 0.09856841554616619, 'holidays_prior_scale': 1.4551383083726088}. Best is trial 345 with value: 9332.17207434874.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/n2xjl1dr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/po9thy28.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73403', 'data', 'file=/tmp/tmptdsgc936/n2xjl1dr.json', 'init=/tmp/tmptdsgc936/po9thy28.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelrbn0r9lw/prophet_model-20230618163503.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:35:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:35:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:35:04,349] Trial 348 finished with value: 9499.349973555027 and parameters: {'changepoint_prior_scale': 0.021740727736144053, 'seasonality_prior_scale': 0.09891790090671909, 'holidays_prior_scale': 1.6829771714174704}. Best is trial 345 with value: 9332.17207434874.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/apj210e4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/xx9gg4np.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59387', 'data', 'file=/tmp/tmptdsgc936/apj210e4.json', 'init=/tmp/tmptdsgc936/xx9gg4np.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modeld9hv0er8/prophet_model-20230618163504.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:35:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:35:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:35:04,810] Trial 349 finished with value: 9326.545877118959 and parameters: {'changepoint_prior_scale': 0.012087088139174694, 'seasonality_prior_scale': 0.3268019855848048, 'holidays_prior_scale': 1.455156849520637}. Best is trial 349 with value: 9326.545877118959.

# %%
# Xây dựng mô hình BSTS với siêu tham số tốt nhất
best_model = Prophet(**best_params)
best_model.fit(train_data)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/9_08xa9o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptdsgc936/4pqzhfma.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70510', 'data', 'file=/tmp/tmptdsgc936/9_08xa9o.json', 'init=/tmp/tmptdsgc936/4pqzhfma.json', 'output', 'file=/tmp/tmptdsgc936/prophet_modelvh_kxgnd/prophet_model-20230618163504.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:35:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:35:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
print("Siêu tham số tối ưu:", best_params)
# Out:
# Siêu tham số tối ưu: {'changepoint_prior_scale': 0.012087088139174694, 'seasonality_prior_scale': 0.3268019855848048, 'holidays_prior_scale': 1.455156849520637}

# %%
# Dự đoán trên tập test và validate
test_forecast = best_model.predict(test_data)
validate_forecast = best_model.predict(validate_data)

# %%
# Dự đoán 30 ngày tiếp theo
future_dates = pd.date_range(start=df['ds'].max(), periods=30, freq='D')
future_data = pd.DataFrame({'ds': future_dates})

future_forecast = best_model.predict(future_data)

# %%
# In kết quả dự đoán
future_forecast['yhat']
# Out:
# 0     62588.134171
# 1     61649.502653
# 2     61717.081597
# 3     62805.375262
# 4     62904.751489
# 5     62903.388174
# 6     62974.768238
# 7     63047.605764
# 8     62100.748317
# 9     62157.297679
# 10    63231.922352
# 11    63315.246642
# 12    63295.788457
# 13    63347.443083
# 14    63399.396051
# 15    62431.010583
# 16    62465.932386
# 17    63519.385691
# 18    63582.545897
# 19    63544.461497
# 20    63579.523054
# 21    63617.362772
# 22    62637.730577
# 23    62664.589765
# 24    63713.406362
# 25    63775.517701
# 26    63740.052945
# 27    63781.403273
# 28    63829.125172
# 29    62862.822515
# Name: yhat, dtype: float64

# %%
# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(train_data['ds'], train_data['y'], label='Thực tế Train')
plt.plot(test_data['ds'], test_data['y'], label='Thực tế Test')
plt.plot(validate_data['ds'], validate_data['y'], label='Thực tế Validate')
plt.plot(test_data['ds'], test_forecast['yhat'], label='Dự đoán (test)')
plt.plot(validate_data['ds'], validate_forecast['yhat'], label='Dự đoán (validate)')
plt.plot(future_dates, future_forecast['yhat'], label='Dự đoán (30 ngày tiếp theo)')
plt.xlabel('Ngày')
plt.ylabel('Giá trị')
plt.title('So sánh giá trị dự đoán và giá trị thực tế trên tập test và validate')
plt.legend()
plt.show()

# %%
# Tính toán độ đo RMSE, MAPE, MSE, MAE và R2 cho test data
rmse = np.sqrt(mean_squared_error(test_data['y'], test_forecast['yhat']))
mape = mean_absolute_percentage_error(test_data['y'], test_forecast['yhat'])*100
mse = mean_squared_error(test_data['y'], test_forecast['yhat'])
mae = mean_absolute_error(test_data['y'], test_forecast['yhat'])
r2 = r2_score(test_data['y'], test_forecast['yhat'])

print("RMSE:", rmse)
print("MAPE:", mape)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 9326.545877118959
# MAPE: 16.341234952550195
# MSE: 86984457.99800465
# MAE: 7701.0606149654905
# R2: -1.7091789335025718

# %%
# Tính toán độ đo RMSE, MAPE, MSE, MAE và R2 cho validate data
rmse = np.sqrt(mean_squared_error(validate_data['y'], validate_forecast['yhat']))
mape = mean_absolute_percentage_error(validate_data['y'], validate_forecast['yhat'])*100
mse = mean_squared_error(validate_data['y'], validate_forecast['yhat'])
mae = mean_absolute_error(validate_data['y'], validate_forecast['yhat'])
r2 = r2_score(validate_data['y'], validate_forecast['yhat'])

print("RMSE:", rmse)
print("MAPE:", mape)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 18716.231882776097
# MAPE: 45.97105714581487
# MSE: 350297335.8898445
# MAE: 18654.183587594685
# R2: -118.86606901930357
