# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install prophet
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.1.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.22.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.5.3)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.4.0)
# Requirement already satisfied: holidays>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.25)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.65.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (5.12.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.10/dist-packages (from holidays>=0.14.2->prophet) (0.3.1)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 23.5 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.2 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 optuna-3.2.0

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
import numpy as np
import optuna
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# Đọc dữ liệu từ tệp CSV
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/csv/VNP.csv')
# Chuyển đổi cột thời gian thành định dạng datetime
data['Date'] = pd.to_datetime(data['Date'])
# Tạo DataFrame dữ liệu đầu vào
df = pd.DataFrame({'ds': data['Date'], 'y': data['Price']})
df
# Out:
#              ds      y
# 0    2017-12-01   5100
# 1    2017-12-04   5800
# 2    2017-12-05   5700
# 3    2017-12-06   5800
# 4    2017-12-07   6300
# ...         ...    ...
# 1225 2023-06-05  14700
# 1226 2023-06-06  14900
# 1227 2023-06-07  14800
# 1228 2023-06-08  14400
# 1229 2023-06-09  14400
#
# [1230 rows x 2 columns]

# %%
# Chia tập dữ liệu thành train-test-validate theo tỉ lệ
n = len(df)
n_train = int(n * 0.7)
n_test = int(n * 0.2)
n_validate = n - n_train - n_test

train_data = df[:n_train]
test_data = df[n_train:n_train + n_test]
validate_data = df[n_train + n_test:]

# %%
# Hàm mục tiêu để tối ưu hóa
def objective(trial):
    # Xác định không gian tìm kiếm cho siêu tham số
    params = {
        'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
        'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
        'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
    }

    # Xây dựng mô hình BSTS với siêu tham số hiện tại
    model = Prophet(**params)
    model.fit(train_data)

    # Dự đoán trên tập test
    forecast = model.predict(test_data)

    # Tính toán độ đo RMSE để đánh giá mô hình
    rmse = mean_squared_error(test_data['y'], forecast['yhat'], squared=False)

    return rmse

# %%
# Tìm giá trị tối ưu cho siêu tham số
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=350)

# Lấy giá trị tối ưu cho siêu tham số
best_params = study.best_params
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:45,228] Trial 55 finished with value: 21836.904455940254 and parameters: {'changepoint_prior_scale': 9.998483523398699, 'seasonality_prior_scale': 0.14510101091978328, 'holidays_prior_scale': 0.05536140972775999}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/gag5r0wy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/qqmsjahi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91022', 'data', 'file=/tmp/tmpbxcsf6ea/gag5r0wy.json', 'init=/tmp/tmpbxcsf6ea/qqmsjahi.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelgme1m2rb/prophet_model-20230618163245.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:46,132] Trial 56 finished with value: 21678.37804436316 and parameters: {'changepoint_prior_scale': 5.653646941633279, 'seasonality_prior_scale': 0.08963339551254954, 'holidays_prior_scale': 0.16454885802189928}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/vjtq_ig4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/mtvwckz_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26794', 'data', 'file=/tmp/tmpbxcsf6ea/vjtq_ig4.json', 'init=/tmp/tmpbxcsf6ea/mtvwckz_.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_model4eke1wmo/prophet_model-20230618163246.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:47,047] Trial 57 finished with value: 21789.269768354156 and parameters: {'changepoint_prior_scale': 7.760537684580463, 'seasonality_prior_scale': 0.2624068887847168, 'holidays_prior_scale': 0.0773210504875164}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/eb8qj8ag.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/aigyyd5u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41765', 'data', 'file=/tmp/tmpbxcsf6ea/eb8qj8ag.json', 'init=/tmp/tmpbxcsf6ea/aigyyd5u.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_model_b12ryrr/prophet_model-20230618163247.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:48,054] Trial 58 finished with value: 22259.067526671584 and parameters: {'changepoint_prior_scale': 2.527726300513252, 'seasonality_prior_scale': 0.19136042589618907, 'holidays_prior_scale': 0.12256175560235917}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/1t_l5jcu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/c2le0z2o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59220', 'data', 'file=/tmp/tmpbxcsf6ea/1t_l5jcu.json', 'init=/tmp/tmpbxcsf6ea/c2le0z2o.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelk7uhd1i9/prophet_model-20230618163248.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:49,436] Trial 59 finished with value: 22021.881286062195 and parameters: {'changepoint_prior_scale': 4.503130473653162, 'seasonality_prior_scale': 0.05619858838913569, 'holidays_prior_scale': 0.03695351340747249}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/s8m4ekqa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/lrrivkpe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33287', 'data', 'file=/tmp/tmpbxcsf6ea/s8m4ekqa.json', 'init=/tmp/tmpbxcsf6ea/lrrivkpe.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modele5y3t50f/prophet_model-20230618163249.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:51,010] Trial 60 finished with value: 21679.34465832813 and parameters: {'changepoint_prior_scale': 3.444701704768442, 'seasonality_prior_scale': 0.1066173949028819, 'holidays_prior_scale': 0.049072371159270635}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/bajxfuc7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/40n_4wr3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2694', 'data', 'file=/tmp/tmpbxcsf6ea/bajxfuc7.json', 'init=/tmp/tmpbxcsf6ea/40n_4wr3.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_model3sdp88z5/prophet_model-20230618163251.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:52,487] Trial 61 finished with value: 21610.414167660187 and parameters: {'changepoint_prior_scale': 4.566675196528805, 'seasonality_prior_scale': 0.16639211418714878, 'holidays_prior_scale': 0.1557252778877955}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/yco9nys3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/m_2r5cq3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43291', 'data', 'file=/tmp/tmpbxcsf6ea/yco9nys3.json', 'init=/tmp/tmpbxcsf6ea/m_2r5cq3.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelk9xcqtv2/prophet_model-20230618163252.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:53,461] Trial 62 finished with value: 21466.22692034616 and parameters: {'changepoint_prior_scale': 5.7281466322359, 'seasonality_prior_scale': 0.16983245949322112, 'holidays_prior_scale': 0.21566949064569554}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/rkk5c3ze.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/cojce64w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23907', 'data', 'file=/tmp/tmpbxcsf6ea/rkk5c3ze.json', 'init=/tmp/tmpbxcsf6ea/cojce64w.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modeli78qt1j8/prophet_model-20230618163253.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:54,383] Trial 63 finished with value: 21690.27328669217 and parameters: {'changepoint_prior_scale': 8.328633310174842, 'seasonality_prior_scale': 0.12159604118958642, 'holidays_prior_scale': 0.09462760687563117}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/ru6tsla5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/t90wc6om.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1509', 'data', 'file=/tmp/tmpbxcsf6ea/ru6tsla5.json', 'init=/tmp/tmpbxcsf6ea/t90wc6om.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelyy55_mjg/prophet_model-20230618163254.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:55,474] Trial 64 finished with value: 21219.383879373458 and parameters: {'changepoint_prior_scale': 5.087757696602912, 'seasonality_prior_scale': 0.07333911590639472, 'holidays_prior_scale': 0.13315989617733245}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/joepq1fo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/8knbi9g3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39106', 'data', 'file=/tmp/tmpbxcsf6ea/joepq1fo.json', 'init=/tmp/tmpbxcsf6ea/8knbi9g3.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_model7onmgu0n/prophet_model-20230618163255.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:56,376] Trial 65 finished with value: 21929.107501436225 and parameters: {'changepoint_prior_scale': 7.257356570760815, 'seasonality_prior_scale': 0.064175621046295, 'holidays_prior_scale': 0.06607299010201738}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/hu45v3kv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/idb3ewdc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27709', 'data', 'file=/tmp/tmpbxcsf6ea/hu45v3kv.json', 'init=/tmp/tmpbxcsf6ea/idb3ewdc.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelex8ij5gm/prophet_model-20230618163256.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:57,301] Trial 66 finished with value: 21841.4683836226 and parameters: {'changepoint_prior_scale': 5.057830407716592, 'seasonality_prior_scale': 0.08161808544560244, 'holidays_prior_scale': 0.2747968651027151}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/lkfnsps8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/yngtxkng.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35736', 'data', 'file=/tmp/tmpbxcsf6ea/lkfnsps8.json', 'init=/tmp/tmpbxcsf6ea/yngtxkng.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modele6qp0r8r/prophet_model-20230618163257.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:58,363] Trial 67 finished with value: 21851.62851219364 and parameters: {'changepoint_prior_scale': 6.287827301621685, 'seasonality_prior_scale': 0.0704395596587628, 'holidays_prior_scale': 0.18649125032811373}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/ms_r31jp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/lqigmp3v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56372', 'data', 'file=/tmp/tmpbxcsf6ea/ms_r31jp.json', 'init=/tmp/tmpbxcsf6ea/lqigmp3v.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelobgnezyc/prophet_model-20230618163258.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:32:59,378] Trial 68 finished with value: 21832.383018598503 and parameters: {'changepoint_prior_scale': 3.179838698070927, 'seasonality_prior_scale': 0.05377016885766333, 'holidays_prior_scale': 0.12921129019164657}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/bg1_11th.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/itqxw9v_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6160', 'data', 'file=/tmp/tmpbxcsf6ea/bg1_11th.json', 'init=/tmp/tmpbxcsf6ea/itqxw9v_.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelxqaee9du/prophet_model-20230618163259.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:32:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:33:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:33:00,153] Trial 69 finished with value: 22404.605252956906 and parameters: {'changepoint_prior_scale': 2.2614493965852596, 'seasonality_prior_scale': 0.09830964122719542, 'holidays_prior_scale': 0.05091761027338856}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/bp4iwlzg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/_n4302sj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7014', 'data', 'file=/tmp/tmpbxcsf6ea/bp4iwlzg.json', 'init=/tmp/tmpbxcsf6ea/_n4302sj.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_model1o_r4eks/prophet_model-20230618163300.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:33:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:33:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:33:01,254] Trial 70 finished with value: 21376.474277359484 and parameters: {'changepoint_prior_scale': 8.343639834218324, 'seasonality_prior_scale': 0.07815984393550428, 'holidays_prior_scale': 0.02805492039160549}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/und1yffk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/0nv9wkd7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61249', 'data', 'file=/tmp/tmpbxcsf6ea/und1yffk.json', 'init=/tmp/tmpbxcsf6ea/0nv9wkd7.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelsvbh9ad4/prophet_model-20230618163301.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:33:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:33:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:33:02,157] Trial 71 finished with value: 22115.497881221945 and parameters: {'changepoint_prior_scale': 8.606676763518323, 'seasonality_prior_scale': 0.08119698148870785, 'holidays_prior_scale': 0.024713821223551966}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/gxemlne8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/mdvbncq1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31138', 'data', 'file=/tmp/tmpbxcsf6ea/gxemlne8.json', 'init=/tmp/tmpbxcsf6ea/mdvbncq1.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelu0ysce7x/prophet_model-20230618163302.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:33:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:33:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:33:03,317] Trial 72 finished with value: 22300.774396797442 and parameters: {'changepoint_prior_scale': 6.250790905173505, 'seasonality_prior_scale': 0.061298676083728146, 'holidays_prior_scale': 0.0337843017110688}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/azfglhgs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/hier33fx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45212', 'data', 'file=/tmp/tmpbxcsf6ea/azfglhgs.json', 'init=/tmp/tmpbxcsf6ea/hier33fx.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modeln7mpqh3j/prophet_model-20230618163303.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:33:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:33:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:33:05,035] Trial 73 finished with value: 21230.84917042941 and parameters: {'changepoint_prior_scale': 8.784653514730843, 'seasonality_prior_scale': 0.07482682967976997, 'holidays_prior_scale': 0.02904487273784612}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/lnz7m_q1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/n4tmk8z3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56452', 'data', 'file=/tmp/tmpbxcsf6ea/lnz7m_q1.json', 'init=/tmp/tmpbxcsf6ea/n4tmk8z3.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_model9nh8e471/prophet_model-20230618163305.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:33:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:33:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:33:06,696] Trial 74 finished with value: 21598.46653286185 and parameters: {'changepoint_prior_scale': 4.055250495433744, 'seasonality_prior_scale': 0.0978658378151836, 'holidays_prior_scale': 0.03909274929134507}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/mlontzhi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/6pyc8son.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76250', 'data', 'file=/tmp/tmpbxcsf6ea/mlontzhi.json', 'init=/tmp/tmpbxcsf6ea/6pyc8son.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_models_ds753c/prophet_model-20230618163306.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:33:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:33:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:33:07,795] Trial 75 finished with value: 21710.78378262085 and parameters: {'changepoint_prior_scale': 5.051406641861158, 'seasonality_prior_scale': 0.06899098380582733, 'holidays_prior_scale': 0.020832768154194027}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/b117_h22.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/1a04x61_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88013', 'data', 'file=/tmp/tmpbxcsf6ea/b117_h22.json', 'init=/tmp/tmpbxcsf6ea/1a04x61_.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_model94cjcmxq/prophet_model-20230618163307.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:33:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:33:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:33:08,987] Trial 76 finished with value: 21664.52676451047 and parameters: {'changepoint_prior_scale': 9.910453221305154, 'seasonality_prior_scale': 0.049727823241979247, 'holidays_prior_scale': 0.060314409298673856}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/a71_uw0m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/8k26bl0j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8679', 'data', 'file=/tmp/tmpbxcsf6ea/a71_uw0m.json', 'init=/tmp/tmpbxcsf6ea/8k26bl0j.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modeln5mvq0vy/prophet_model-20230618163309.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:33:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:33:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:33:09,828] Trial 77 finished with value: 21928.11158385234 and parameters: {'changepoint_prior_scale': 6.898061188548052, 'seasonality_prior_scale': 0.13389560333392864, 'holidays_prior_scale': 0.018845914863100565}. Best is trial 41 with value: 20675.919820456063.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# ...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/ztn2p03n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/2e7o2e9_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65101', 'data', 'file=/tmp/tmpbxcsf6ea/ztn2p03n.json', 'init=/tmp/tmpbxcsf6ea/2e7o2e9_.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modello6b4wcq/prophet_model-20230618163806.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:38:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:38:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:38:07,654] Trial 342 finished with value: 21774.44212325036 and parameters: {'changepoint_prior_scale': 7.702253708639489, 'seasonality_prior_scale': 0.05404826251704714, 'holidays_prior_scale': 0.10534808641568201}. Best is trial 201 with value: 20441.887670381548.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/5ugo9184.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/zu0b6eoi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90786', 'data', 'file=/tmp/tmpbxcsf6ea/5ugo9184.json', 'init=/tmp/tmpbxcsf6ea/zu0b6eoi.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modeler6k1ifr/prophet_model-20230618163807.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:38:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:38:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:38:09,043] Trial 343 finished with value: 21195.204963935586 and parameters: {'changepoint_prior_scale': 6.242208026455931, 'seasonality_prior_scale': 0.2978955985077548, 'holidays_prior_scale': 4.331439704051254}. Best is trial 201 with value: 20441.887670381548.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/h_j4mbi2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/bveqvcnz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54220', 'data', 'file=/tmp/tmpbxcsf6ea/h_j4mbi2.json', 'init=/tmp/tmpbxcsf6ea/bveqvcnz.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelftu2ndwl/prophet_model-20230618163809.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:38:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:38:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:38:10,139] Trial 344 finished with value: 20660.92113607712 and parameters: {'changepoint_prior_scale': 8.066829423858858, 'seasonality_prior_scale': 0.25831800097706387, 'holidays_prior_scale': 9.897507656998483}. Best is trial 201 with value: 20441.887670381548.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/rmi9tagc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/aeat1xb5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41322', 'data', 'file=/tmp/tmpbxcsf6ea/rmi9tagc.json', 'init=/tmp/tmpbxcsf6ea/aeat1xb5.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelexcdxfgw/prophet_model-20230618163810.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:38:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:38:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:38:11,262] Trial 345 finished with value: 21277.0404182614 and parameters: {'changepoint_prior_scale': 7.3114179464987386, 'seasonality_prior_scale': 0.2559081545619527, 'holidays_prior_scale': 6.484774487012798}. Best is trial 201 with value: 20441.887670381548.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/ykgo13pj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/oq4omry6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48113', 'data', 'file=/tmp/tmpbxcsf6ea/ykgo13pj.json', 'init=/tmp/tmpbxcsf6ea/oq4omry6.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelked0pfrp/prophet_model-20230618163811.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:38:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:38:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:38:12,456] Trial 346 finished with value: 21300.158606418536 and parameters: {'changepoint_prior_scale': 9.99307639814616, 'seasonality_prior_scale': 0.3330979273619779, 'holidays_prior_scale': 8.825895451154345}. Best is trial 201 with value: 20441.887670381548.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/7yiv3852.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/ogloj0qn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1655', 'data', 'file=/tmp/tmpbxcsf6ea/7yiv3852.json', 'init=/tmp/tmpbxcsf6ea/ogloj0qn.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_model1psxv_kq/prophet_model-20230618163812.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:38:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:38:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:38:12,990] Trial 347 finished with value: 23971.66000139284 and parameters: {'changepoint_prior_scale': 0.017836522613353847, 'seasonality_prior_scale': 0.27296082425728796, 'holidays_prior_scale': 8.077333966690025}. Best is trial 201 with value: 20441.887670381548.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/ms80ryvl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/7lemiiwi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2452', 'data', 'file=/tmp/tmpbxcsf6ea/ms80ryvl.json', 'init=/tmp/tmpbxcsf6ea/7lemiiwi.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modeloiqik3l7/prophet_model-20230618163813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:38:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:38:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:38:13,964] Trial 348 finished with value: 21553.951893951333 and parameters: {'changepoint_prior_scale': 8.066700353277097, 'seasonality_prior_scale': 0.6811911075802658, 'holidays_prior_scale': 9.96946690740775}. Best is trial 201 with value: 20441.887670381548.
# <ipython-input-6-bb80d6b1eb20>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'changepoint_prior_scale': trial.suggest_loguniform('changepoint_prior_scale', 0.01, 10.0),
# <ipython-input-6-bb80d6b1eb20>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'seasonality_prior_scale': trial.suggest_loguniform('seasonality_prior_scale', 0.01, 1.0),
# <ipython-input-6-bb80d6b1eb20>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'holidays_prior_scale': trial.suggest_loguniform('holidays_prior_scale', 0.01, 10.0),
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/98zhe__e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/2fyw4tva.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71024', 'data', 'file=/tmp/tmpbxcsf6ea/98zhe__e.json', 'init=/tmp/tmpbxcsf6ea/2fyw4tva.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_modelx1hxqy5x/prophet_model-20230618163814.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:38:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:38:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [I 2023-06-18 16:38:15,000] Trial 349 finished with value: 22235.38528105839 and parameters: {'changepoint_prior_scale': 1.9309147362941768, 'seasonality_prior_scale': 0.2353345418504924, 'holidays_prior_scale': 1.2749283755266663}. Best is trial 201 with value: 20441.887670381548.

# %%
# Xây dựng mô hình BSTS với siêu tham số tốt nhất
best_model = Prophet(**best_params)
best_model.fit(train_data)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/ua461ere.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbxcsf6ea/hyn3hizx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24536', 'data', 'file=/tmp/tmpbxcsf6ea/ua461ere.json', 'init=/tmp/tmpbxcsf6ea/hyn3hizx.json', 'output', 'file=/tmp/tmpbxcsf6ea/prophet_model_2u7ic3n/prophet_model-20230618163815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:38:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:38:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
print("Siêu tham số tối ưu:", best_params)
# Out:
# Siêu tham số tối ưu: {'changepoint_prior_scale': 8.93360230684565, 'seasonality_prior_scale': 0.27893580204009466, 'holidays_prior_scale': 0.03955952600845879}

# %%
# Dự đoán trên tập test và validate
test_forecast = best_model.predict(test_data)
validate_forecast = best_model.predict(validate_data)

# %%
# Dự đoán 30 ngày tiếp theo
future_dates = pd.date_range(start=df['ds'].max(), periods=30, freq='D')
future_data = pd.DataFrame({'ds': future_dates})

future_forecast = best_model.predict(future_data)

# %%
# In kết quả dự đoán
future_forecast['yhat']
# Out:
# 0     53995.583916
# 1     54089.781923
# 2     54179.537363
# 3     54220.366117
# 4     54355.422394
# 5     54498.282685
# 6     54580.966056
# 7     54641.206406
# 8     54740.571370
# 9     54829.797987
# 10    54864.050945
# 11    54986.284716
# 12    55110.035344
# 13    55167.444046
# 14    55196.528165
# 15    55259.294174
# 16    55307.063031
# 17    55295.714008
# 18    55369.028700
# 19    55441.461541
# 20    55446.139572
# 21    55422.107719
# 22    55432.415012
# 23    55429.412827
# 24    55369.972047
# 25    55398.801637
# 26    55431.195667
# 27    55401.012214
# 28    55347.900985
# 29    55335.375590
# Name: yhat, dtype: float64

# %%
# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(train_data['ds'], train_data['y'], label='Thực tế Train')
plt.plot(test_data['ds'], test_data['y'], label='Thực tế Test')
plt.plot(validate_data['ds'], validate_data['y'], label='Thực tế Validate')
plt.plot(test_data['ds'], test_forecast['yhat'], label='Dự đoán (test)')
plt.plot(validate_data['ds'], validate_forecast['yhat'], label='Dự đoán (validate)')
plt.plot(future_dates, future_forecast['yhat'], label='Dự đoán (30 ngày tiếp theo)')
plt.xlabel('Ngày')
plt.ylabel('Giá trị')
plt.title('So sánh giá trị dự đoán và giá trị thực tế trên tập test và validate')
plt.legend()
plt.show()

# %%
# Tính toán độ đo RMSE, MAPE, MSE, MAE và R2 cho test data
rmse = np.sqrt(mean_squared_error(test_data['y'], test_forecast['yhat']))
mape = mean_absolute_percentage_error(test_data['y'], test_forecast['yhat'])*100
mse = mean_squared_error(test_data['y'], test_forecast['yhat'])
mae = mean_absolute_error(test_data['y'], test_forecast['yhat'])
r2 = r2_score(test_data['y'], test_forecast['yhat'])

print("RMSE:", rmse)
print("MAPE:", mape)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 20441.887670381548
# MAPE: 118.9732281193207
# MSE: 417870771.5284971
# MAE: 16922.93330272658
# R2: -13.214533423495512

# %%
# Tính toán độ đo RMSE, MAPE, MSE, MAE và R2 cho validate data
rmse = np.sqrt(mean_squared_error(validate_data['y'], validate_forecast['yhat']))
mape = mean_absolute_percentage_error(validate_data['y'], validate_forecast['yhat'])*100
mse = mean_squared_error(validate_data['y'], validate_forecast['yhat'])
mae = mean_absolute_error(validate_data['y'], validate_forecast['yhat'])
r2 = r2_score(validate_data['y'], validate_forecast['yhat'])

print("RMSE:", rmse)
print("MAPE:", mape)
print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 39611.31205743997
# MAPE: 351.91313927382123
# MSE: 1569056042.911889
# MAE: 39602.39601984197
# R2: -835.4263733067271
